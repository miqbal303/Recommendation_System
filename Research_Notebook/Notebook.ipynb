# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('NaukriData_Data Science.csv')
df2 = pd.read_csv('NaukriData_data analytics.csv')

# %%
df1.head(10)
# Out:
#                                           Job_Titles  \
# 0                      Senior Manager - Data Science
# 1      Advance Analytical and Data Sciences -Manager
# 2  Manager - Digital Product Analytics [Data Scie...
# 3                               Data Science Manager
# 4                               Data Science Manager
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  GN - Strategy - MC - T&O - NLP Data Science - ...
# 9                        Senior Data Science Analyst
#
#                        Company_Names Experience_Required Package_Details  \
# 0                   AMERICAN EXPRESS             4-8 Yrs   Not disclosed
# 1                  G R Infraprojects            6-10 Yrs   Not disclosed
# 2                               Resy             4-8 Yrs   Not disclosed
# 3          Foreign IT Consulting MNC             1-3 Yrs   Not disclosed
# ...

# %%
df1.tail()
# Out:
#       Job_Titles Company_Names Experience_Required Package_Details Locations  \
# 47186       None          None                None            None      None
# 47187       None          None                None            None      None
# 47188       None          None                None            None      None
# 47189       None          None                None            None      None
# 47190       None          None                None            None      None
#
#       Skills                                           Post_Url Post_Time
# 47186   None  https://www.naukri.com/job-listings-data-scien...      None
# 47187   None  https://www.naukri.com/job-listings-data-scien...      None
# 47188   None  https://www.naukri.com/job-listings-head-data-...      None
# 47189   None  https://www.naukri.com/job-listings-data-scien...      None
# 47190   None  https://www.naukri.com/job-listings-senior-dat...      None

# %%
df2.head()
# Out:
#                                           Job_Titles  \
# 0                     Lead Analyst, Data & Analytics
# 1  Director Data Analytics (Immediate Joiner pref...
# 2                                Data Analytics Lead
# 3                             Data Analytics Analyst
# 4                             Data Analytics Analyst
#
#                Company_Names Experience_Required Package_Details  \
# 0                        ANZ             4-6 Yrs   Not disclosed
# 1        Techneplus Software           10-15 Yrs   Not disclosed
# 2                    Gartner             5-8 Yrs   Not disclosed
# 3  Leading Indian IT Company             4-7 Yrs   Not disclosed
# 4         Foreign MNC in BPO             7-9 Yrs   Not disclosed
#
#                                            Locations  \
# 0                                Bangalore/Bengaluru
# 1  Noida, Uttar Pradesh, Bangalore/ Bengaluru, Ka...
# 2                                   Gurgaon/Gurugram
# ...

# %%
df2.tail()
# Out:
#                                  Job_Titles    Company_Names  \
# 20059   Senior Magento Developer (Frontend)   Terrific Minds
# 20060              Senior Magento Developer   Terrific Minds
# 20061                  Full Stack Developer  Indium Software
# 20062         Consultant - Azure Databricks         Tredence
# 20063  Consultant - Azure+SQL (HealthEM.AI)         Tredence
#
#       Experience_Required Package_Details  \
# 20059                 NaN   Not disclosed
# 20060                 NaN   Not disclosed
# 20061                 NaN   Not disclosed
# 20062                 NaN   Not disclosed
# 20063                 NaN             NaN
#
#                                                Locations Skills  \
# 20059                                Bangalore/Bengaluru    NaN
# 20060  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    NaN
# 20061  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...    NaN
# 20062                                                NaN    NaN
# ...

# %%
# shape of data
print("DF1 shape: ", df1.shape)
print("DF2 shape: ", df2.shape)
# Out:
# DF1 shape:  (47191, 8)
# DF2 shape:  (20064, 8)

# %%
if list(df1.columns) == list(df2.columns):
    print("Column names are the same in both datasets")
else:
    print("Column names are not the same")
# Out:
# Column names are the same in both datasets

# %%
# combine both dataset
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#                                           Job_Titles  \
# 0                      Senior Manager - Data Science
# 1      Advance Analytical and Data Sciences -Manager
# 2  Manager - Digital Product Analytics [Data Scie...
# 3                               Data Science Manager
# 4                               Data Science Manager
#
#                        Company_Names Experience_Required Package_Details  \
# 0                   AMERICAN EXPRESS             4-8 Yrs   Not disclosed
# 1                  G R Infraprojects            6-10 Yrs   Not disclosed
# 2                               Resy             4-8 Yrs   Not disclosed
# 3          Foreign IT Consulting MNC             1-3 Yrs   Not disclosed
# 4  Fortune India 500 Company in FMCG             4-9 Yrs   Not disclosed
#
#                                            Locations  \
# 0                                   Gurgaon/Gurugram
# 1                         Gurgaon/ Gurugram, Haryana
# ...

# %%
print("Shape of data: ",df.shape)
# Out:
# Shape of data:  (67255, 8)

# %%
# check missing values
df.isnull().sum()
# Out:
# Job_Titles             3761
# Company_Names          4026
# Experience_Required     296
# Package_Details          18
# Locations                29
# Skills                  283
# Post_Url               7355
# Post_Time                 5
# dtype: int64

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 24401

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67255 entries, 0 to 67254
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Job_Titles           63494 non-null  object
#  1   Company_Names        63229 non-null  object
#  2   Experience_Required  66959 non-null  object
#  3   Package_Details      67237 non-null  object
#  4   Locations            67226 non-null  object
#  5   Skills               66972 non-null  object
#  6   Post_Url             59900 non-null  object
#  7   Post_Time            67250 non-null  object
# dtypes: object(8)
# memory usage: 4.1+ MB

# %% [markdown]
# All Values are categoricals

# %%
#description
df.describe().T
# Out:
#                      count unique  \
# Job_Titles           63494  13447
# Company_Names        63229   7817
# Experience_Required  66959    191
# Package_Details      67237    426
# Locations            67226   1758
# Skills               66972  20450
# Post_Url             59900  22819
# Post_Time            67250     43
#
#                                                                    top   freq
# Job_Titles                                                        None   9820
# Company_Names                                                     None   7345
# Experience_Required                                               None  11203
# Package_Details                                          Not disclosed  52611
# Locations                                          Bangalore/Bengaluru  12909
# Skills                                                            None   9162
# Post_Url             https://www.naukri.com/job-listings-senior-man...   1471
# ...

# %%
# drop duplicate and missing values
df = df.drop_duplicates()
df = df.dropna()
# Replace "None" values with actual NaN values
df.replace('None', pd.NA, inplace=True)

# Drop rows with NaN values in any column
df.dropna(axis=0, how='any', inplace=True)

# %%
df.head(30)
# Out:
#                                            Job_Titles  \
# 0                       Senior Manager - Data Science
# 1       Advance Analytical and Data Sciences -Manager
# 2   Manager - Digital Product Analytics [Data Scie...
# 8   GN - Strategy - MC - T&O - NLP Data Science - ...
# 9                         Senior Data Science Analyst
# 10               Data Science - Senior Data Scientist
# 11                        Senior Manager-Data Science
# 12  GN - Strategy - MC - T&O - NLP Data Science - ...
# 13            Senior Divisional Manager- Data Science
# 14  Head Data Science -Leading Company - Mumbai / ...
# 15                        Senior Analyst Data Science
# 16                              Data Science Engineer
# 17                       Senior Analyst, Data Science
# 18                        Data Science Domain Manager
# 19                              Data Science Engineer
# 20                            Data Science Consultant
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
# Filter job listings based on skills using NLP techniques
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\miqba\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\miqba\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\miqba\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df[["Experience_Required","Skills"]]
# Out:
#       Experience_Required                                             Skills
# 0                 4-8 Yrs  Text miningCareer developmentdata scienceFinan...
# 1                6-10 Yrs  Advanced Statistical AnalysisData Governance a...
# 2                 4-8 Yrs  Product managementCareer developmentOperations...
# 8                8-12 Yrs  deep learningdata scienceGCPNeural networksMac...
# 9               15-24 Yrs  Data SciencepythonPyTorchArtificial Intelligen...
# ...                   ...                                                ...
# 67241             3-6 Yrs  UnixManager Quality AssuranceTest strategyBusi...
# 67242             3-6 Yrs  Computer scienceC++CNetworkingFocusDebuggingMa...
# 67243            8-13 Yrs  Front endjQueryLinuxMySQLJavascriptAgilePHPWor...
# 67244             2-6 Yrs  DrupalAnalyticalIntranetMySQLAgilePHPApplicati...
# 67245             2-6 Yrs  IT servicesSANSOCApacheMiddlewareVirtualizatio...
#
# [37019 rows x 2 columns]

# %%
# Preprocess data
df["Skills"] = df["Skills"].apply(lambda x: word_tokenize(x.lower()))
df["Experience_Required"] = df["Experience_Required"].str.extract('(\d+)').astype(float)

# %%
df[["Experience_Required","Skills"]]
# Out:
#        Experience_Required                                             Skills
# 0                      4.0  [text, miningcareer, developmentdata, sciencef...
# 1                      6.0  [advanced, statistical, analysisdata, governan...
# 2                      4.0  [product, managementcareer, developmentoperati...
# 8                      8.0  [deep, learningdata, sciencegcpneural, network...
# 9                     15.0  [data, sciencepythonpytorchartificial, intelli...
# ...                    ...                                                ...
# 67241                  3.0  [unixmanager, quality, assurancetest, strategy...
# 67242                  3.0  [computer, sciencec++cnetworkingfocusdebugging...
# 67243                  8.0  [front, endjquerylinuxmysqljavascriptagilephpw...
# 67244                  2.0  [drupalanalyticalintranetmysqlagilephpapplicat...
# 67245                  2.0  [it, servicessansocapachemiddlewarevirtualizat...
#
# [37019 rows x 2 columns]

# %%
df
# Out:
#                                               Job_Titles  \
# 0                          Senior Manager - Data Science
# 1          Advance Analytical and Data Sciences -Manager
# 2      Manager - Digital Product Analytics [Data Scie...
# 8      GN - Strategy - MC - T&O - NLP Data Science - ...
# 9                            Senior Data Science Analyst
# ...                                                  ...
# 67241                              Informatica Developer
# 67242  Video Computing Software Product Management Sp...
# 67243                                  Magento Architect
# 67244                         Senior Salesforce Engineer
# 67245                      Manager / Senior Manager, HTA
#
#                                Company_Names  Experience_Required  \
# 0                           AMERICAN EXPRESS                  4.0
# 1                          G R Infraprojects                  6.0
# 2                                       Resy                  4.0
# ...

# %%
df['Post_Url'][0]
# Out:
# 'https://www.naukri.com/job-listings-senior-manager-data-science-american-express-company-gurgaon-gurugram-4-to-8-years-261023500868'

# %%
from wordcloud import WordCloud
# Features to create word clouds for
features = ["Job_Titles", "Company_Names", "Locations", "Skills"]

# Plot word clouds for each feature
plt.figure(figsize=(15, 8))
for i, feature in enumerate(features):
    if feature == "Skills":
        # Convert the list of skills to a single string
        text = ' '.join(' '.join(skill) for skill in df[feature])
    else:
        text = ' '.join(df[feature])
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    plt.subplot(2, 2, i + 1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(feature)
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Preprocessing functions
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    words = word_tokenize(text.lower())
    words = [word for word in words if word.isalnum()]
    words = [word for word in words if word not in stop_words]
    words = [lemmatizer.lemmatize(word) for word in words]
    return words

# %%
def convert_post_time(post_time):
    try:
        days_ago = int(post_time.split(' ')[0])
        return days_ago
    except ValueError:
        return None

def recommend_jobs(skills_input, experience_input, location_input, data):
    # Preprocess user input
    skills_input = preprocess_text(' '.join(skills_input))

    # Filter based on user input
    filtered_jobs = data[data["Skills"].apply(lambda x: all(skill in x for skill in skills_input))]

    # Optionally, filter based on experience
    if experience_input:
        filtered_jobs = filtered_jobs[filtered_jobs["Experience_Required"] >= float(experience_input)]

    # Optionally, filter based on location
    if location_input:
        filtered_jobs = filtered_jobs[filtered_jobs["Locations"].str.contains(location_input, case=False, na=False)]

    # Convert "Post_Time" to numeric days ago
    filtered_jobs["Post_Time_Num"] = filtered_jobs["Post_Time"].apply(convert_post_time)

    # Sort by "Post_Time_Num" in descending order and get the top 5 jobs
    filtered_jobs = filtered_jobs.sort_values(by="Post_Time_Num", ascending=False).head(5)

    return filtered_jobs[["Job_Titles", "Company_Names", "Package_Details", "Locations", "Post_Url", "Post_Time"]]

# %%
# Function to display the results in a DataFrame or provide a suggestion
def display_recommendations(recommended_jobs):
    if recommended_jobs.empty:
        print("No matching jobs found. Try with different keywords.")
    else:
        pd.set_option('display.max_colwidth', -1)
        print(recommended_jobs)

# Example usage:
skills_input = input("Enter your skills (comma-separated): ").lower().split(',')
experience_input = input("Enter your experience (optional): ")
location_input = input("Enter your preferred location (optional): ")
# Out:
# Enter your skills (comma-separated): machine
# Enter your experience (optional):
# Enter your preferred location (optional):

# %%
recommended_jobs = recommend_jobs(skills_input, experience_input, location_input, df)
display_recommendations(recommended_jobs)
# Out:
#                    Job_Titles                    Company_Names  \
# 52631  Applied Data Scientist  Carrier
# 50616  Lead Data Scientist     Ally-Executive
# 51030  Sr. Data Scientist      Godswill Management Consultants
# 4573   Business Analyst        Vertafore
# 3912   Analyst - eDiscovery    Apptunix
#
#       Package_Details  \
# 52631  Not disclosed
# 50616  Not disclosed
# 51030  Not disclosed
# 4573   Not disclosed
# 3912   Not disclosed
#
#                                                                                                                                                                                             Post_Url  \
# 52631  https://www.naukri.com/job-listings-supply-chain-analyst-power-bi-carrier-hyderabad-secunderabad-telangana-gurgaon-gurugram-haryana-2-to-7-years-280923003677
# 50616  https://www.naukri.com/job-listings-lead-data-scientist-ally-executive-bangalore-bengaluru-8-to-12-years-270923907353
# ...

# %%
# !pip install moviepy
# Out:
# ...
#      ---------------------------------------- 0.0/388.3 kB ? eta -:--:--
#      ----------------------- -------------- 235.5/388.3 kB 7.0 MB/s eta 0:00:01
#      -------------------------------------- 388.3/388.3 kB 6.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Obtaining dependency information for requests<3.0,>=2.8.1 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# ...

# %%
import moviepy.editor as mp

# Define the input video file path and output GIF file path
input_video_path = 'Streamlit_Job_recommendation.mp4'
output_gif_path = 'output.gif'

# Load the video
clip = mp.VideoFileClip(input_video_path)

# Convert the video to GIF
clip.write_gif(output_gif_path)

print("GIF conversion complete.")
# Out:
# MoviePy - Building file output.gif with imageio.
# GIF conversion complete.
